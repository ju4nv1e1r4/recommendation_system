# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/external/dataset.csv')

# %%
male = df[df['gender'] == 'Male']

male['age'].value_counts(normalize=True)
# Out:
# age
# 54    0.034694
# 31    0.032653
# 57    0.032653
# 62    0.032653
# 34    0.028571
# 50    0.028571
# 23    0.028571
# 22    0.026531
# 41    0.026531
# 51    0.026531
# 21    0.026531
# 49    0.024490
# 30    0.024490
# 64    0.024490
# 61    0.024490
# 43    0.024490
# 63    0.022449
# 42    0.022449
# 25    0.022449
# 47    0.022449
# 32    0.020408
# 38    0.020408
# 19    0.020408
# 40    0.020408
# 24    0.020408
# 29    0.020408
# 27    0.020408
# 46    0.018367
# 52    0.018367
# 39    0.018367
# 56    0.018367
# 20    0.018367
# 53    0.018367
# 60    0.018367
# 37    0.016327
# 55    0.016327
# 18    0.016327
# 35    0.016327
# 45    0.016327
# 48    0.016327
# 59    0.016327
# 44    0.014286
# 36    0.014286
# 28    0.014286
# 26    0.014286
# 58    0.012245
# 33    0.008163
# Name: proportion, dtype: float64

# %%
male['age'].plot(kind='hist', bins=45)
# Out:
# <Axes: ylabel='Frequency'>

# %%
female = df[df['gender'] == 'Female']

female['age'].plot(kind='hist', bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
male['age'].max()
# Out:
# np.int64(64)
