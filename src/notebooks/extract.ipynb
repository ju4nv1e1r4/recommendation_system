# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/external/retail-sales-dataset.zip')
df.sample(10)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 239             240  2023-02-06     CUST240  Female   23           Beauty
# 493             494  2023-09-18     CUST494  Female   42           Beauty
# 863             864  2023-07-27     CUST864  Female   51      Electronics
# 934             935  2023-09-09     CUST935  Female   34           Beauty
# 756             757  2023-12-25     CUST757  Female   43      Electronics
# 117             118  2023-05-16     CUST118  Female   30      Electronics
# 968             969  2023-04-19     CUST969  Female   40         Clothing
# 837             838  2023-05-13     CUST838    Male   47      Electronics
# 131             132  2023-09-10     CUST132    Male   42      Electronics
# 836             837  2023-07-01     CUST837    Male   18           Beauty
#
#      Quantity  Price per Unit  Total Amount
# 239         1             300           300
# 493         4              50           200
# 863         1             500           500
# 934         1              50            50
# 756         4             300          1200
# 117         4             500          2000
# 968         3             300           900
# 837         2             300           600
# 131         4              50           200
# 836         3              30            90

# %%
# padronizar (letras minúsculas)

# %%
# tratamento de dtypes
